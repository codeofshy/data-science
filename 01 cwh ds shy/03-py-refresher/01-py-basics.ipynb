# %%
name = "Alice"
age = 25
is_student = True

# %%
s1, age1, status = "shy", 27, "M" # all 3 variables are assigned in 1 line

# %%
print(f"Hello the my name is {s1}. I am {age1} year young and my marital status is {status}")
# Out:
# Hello the my name is shy. I am 27 year young and my marital status is M

# %%
type(age)
# Out:
# int

# %% [markdown]
# ## type of variable

# %%
type(name)
# Out:
# str

# %%
bool(10)
# Out:
# True

# %% [markdown]
# ## type casting

# %%
a = 345

# %%
type(a)
# Out:
# int

# %%
str(a)
# Out:
# '345'

# %%
float(a)
# Out:
# 345.0

# %%
bool(a)
# Out:
# True

# %%
complex(a)
# Out:
# (345+0j)
