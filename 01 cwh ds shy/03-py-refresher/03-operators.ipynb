# %% [markdown]
# ## Operators in python
# ## arithematic operator

# %%
a = 10
b = 2

# %%
a + b
# Out:
# 12

# %%
a - b
# Out:
# 8

# %%
a * b
# Out:
# 20

# %%
a**b
# Out:
# 100

# %%
a/b
# Out:
# 5.0

# %%
a//b
# Out:
# 5

# %%
7 / 2 # division will always return float
# Out:
# 3.5

# %%
7 // 2 # floor division will give you only integer
# Out:
# 3

# %%
7 % 2 # modulo will return you the remainder
# Out:
# 1

# %%
9 % 5
# Out:
# 4

# %% [markdown]
# ## Comparison operator
# This will always return value in true or false

# %%
a = 4
b = 3

# %%
a > b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a <= b
# Out:
# False

# %%
4 < 4
# Out:
# False

# %%
4 <= 4
# Out:
# True

# %%
a != b
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
4 == 3
# Out:
# False

# %%
3 == 3
# Out:
# True

# %% [markdown]
# ## logical Operator
#
# combination of and, or,not
# These are operated in booleans

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not (True and False)
# Out:
# True

# %%
not (True and True)
# Out:
# False

# %%
not (False and False)
# Out:
# True

# %%
# similarly we can also use with or

# %%
a = 5
b = 2

# %%
a and b
# Out:
# 3

# %%
a and a
# Out:
# 5

# %%
b and b
# Out:
# 3

# %% [markdown]
# ## Bitwise operator
#
# First your value will be converted to binary code and then the operator after that you get the result.
#
# & - | :  are the bitwise operator

# %%
 5 & 3
# Out:
# 1

# %%
5 | 3
# Out:
# 7

# %% [markdown]
# ## Assignment operator

# %%
a = 5 # we have assigned int 5 to variable a

# %%
a += 2 # a = a + 2

# %%
a
# Out:
# 7

# %%
a -= 2

# %%
a
# Out:
# 5

# %%
a *= 2

# %%
a
# Out:
# 10

# %%
a **= 2

# %%
a
# Out:
# 100

# %%
a = 5

# %%
a /= 2

# %%
a
# Out:
# 2.5

# %%
a = 5

# %%
a //= 2

# %%
a
# Out:
# 2

# %% [markdown]
# ## Membership operator
# - in
# - not in
# - is
# - not is

# %%
name = 'shayan ahmed khan'
fruits = ['apple', 'banana', 'kiwi', 'tomato', 'pear']

# %%
'ahmed' in name
# Out:
# True

# %%
'player' in name
# Out:
# False

# %%
name in name
# Out:
# True

# %%
'player' not in name
# Out:
# True

# %%
'kiwi' in fruits
# Out:
# True

# %%
'brinjal'  not in fruits
# Out:
# True

# %%
'one' is 1
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Users\shaya\AppData\Local\Temp\ipykernel_10836\754481585.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   'one' is 1
# False

# %%
'ali' is 'ali'
# Out:
# True

# %%
'ali' is not 'ali'
# Out:
# <>:1: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# C:\Users\shaya\AppData\Local\Temp\ipykernel_10836\523577261.py:1: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   'ali' is not 'ali'
# False

# %%
'ali' is not 'abi talib'
# Out:
# True
