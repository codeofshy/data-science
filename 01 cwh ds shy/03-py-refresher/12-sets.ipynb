# %% [markdown]
# ## sets
# - A set in Python is an unordered, mutable, and unique collection of elements.
# - It does not allow duplicate values.
#
# Key Properties of Sets:
# - Unordered: No indexing or slicing.
# - Unique Elements: Duplicates are automatically removed.
# - Mutable: You can add or remove elements.

# %%
# Empty set (must use set(), not {})
empty_set = set()

# Set with elements
numbers = {1, 2, 3, 4, 5}

# Mixed data types
mixed_set = {1, "Hello", 3.14, True}

# Creating a set from a list
unique_numbers = set([1, 2, 2, 3, 4, 4, 5])
print(unique_numbers)  # {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5}

# %%
# empty list
type([])
# Out:
# list

# %%
# empty tuple
type(())
# Out:
# tuple

# %%
# empty dict
type({})
# Out:
# dict

# %%
# empty set
type(set())
# Out:
# set

# %%
# sets are unique
s = {1, 2, 3, 4, 5, 4, 4}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(444)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 444}

# %%
s.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s.sort()
#
# AttributeError: 'set' object has no attribute 'sort'

# %%
s[1]

# %%
s.pop()

# %%
s.pop()

# %%
s

# %%
# if the element is not present it will give us an error
s.remove(17)

# %%
# if the element is not present it will give no error
s.discard(17)

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
# Union – combines all unique elements
print(set1 | set2)            # {1, 2, 3, 4, 5, 6}
print(set1.union(set2))       # same result

# %%
# Intersection – common elements
print(set1 & set2)            # {3, 4}
print(set1.intersection(set2))# same result

# %%
# Difference – in set1 but not in set2
print(set1 - set2)            # {1, 2}
print(set1.difference(set2))  # same result

# %%
# Symmetric Difference – in either set, but not both
print(set1 ^ set2)                     # {1, 2, 5, 6}
print(set1.symmetric_difference(set2))# same result

# %%
s = {1, 2, 3, 5, 66, 8}

# %%
type(s)
# Out:
# set

# %%
s1 = {1, 3, 66}

# %%
s1.issubset(s)
# Out:
# True

# %%
s.issuperset(s1)
# Out:
# True

# %%
l = [1,2,3,3,3,5,6,77,77,7]

# %%
# we can use the sets to get the unique items in list
# by typecasting list to sets
s = set(l)

# %%
s
# Out:
# {1, 2, 3, 5, 6, 7, 77}

# %%
l = list(s)

# %%
l
# Out:
# [1, 2, 3, 5, 6, 7, 77]
