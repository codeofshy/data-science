# %% [markdown]
# ## Input in python
# - By default it takes input as a string.

# %%
name = input('Enter your name :')
# Out:
# Enter your name : Shayan

# %%
age =  input("Enter your age :")
# Out:
# Enter your age : 12

# %%
a = input('enter a number :')
# Out:
# enter a number : 6

# %%
b = input('enter a number :')
# Out:
# enter a number : 4

# %%
a + b # here, we recieved string concatenation as inputs are bydefaul str
# Out:
# '64'

# %%
int(a) + int(b)
# Out:
# 10

# %%
future_age = int(input('Enter your age to see after 10 year what will be your age :')) + 10
# Out:
# Enter your age to see after 10 year what will be your age : 25

# %%
future_age
