# %% [markdown]
# ## list
# - list is a container enclosed with [].
# - list is ordered.
# - can hold different data types.
# - Is mutable and if any method is applied the list is updated.
# - It can have duplicate items.

# %%
l1 = ['shayan', 27, 3.14, True]

# %%
l1[0]
# Out:
# 'shayan'

# %%
# Empty list
my_list = []

# List with elements
numbers = [1, 2, 3, 4, 5]

# Mixed data types
mixed_list = [1, "Hello", 3.14, True]

# %%
# list is extended by other list
numbers.extend(mixed_list)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5, 1, 'Hello', 3.14, True]

# %%
n = [1, 2, 55, 87, 69, 33]

# %%
n[0]
# Out:
# 1

# %%
n[-1]
# Out:
# 33

# %%
n[::2]
# Out:
# [1, 55, 69]

# %%
# This is how we reverse the string
n[::-1]
# Out:
# [33, 69, 87, 55, 2, 1]

# %%
n
# Out:
# [1, 2, 55, 87, 69, 33]

# %% [markdown]
# Methods on list

# %%
n.append(200)

# %%
n
# Out:
# [1, 2, 55, 87, 69, 33, 200]

# %%
n.index(2)
# Out:
# 1

# %%
n.insert(0, 1710)

# %%
n
# Out:
# [1710, 1, 2, 55, 87, 69, 33, 200]

# %%
# when we use the pop method it does 2 thing at once
# removes the last item of the list and also returns that item
# we can store this value in the variable
n.pop()
# Out:
# 200

# %%
n
# Out:
# [1710, 1, 2, 55, 87, 69, 33]

# %%
last_item =  n.pop()

# %%
last_item
# Out:
# 33

# %%
# we can also pop the item from a certain index

# %%
n.pop(0)
# Out:
# 1710

# %%
n.pop(3)
# Out:
# 87

# %%
l = [33, 6, 1, 667, 32, 90, 100, 33, 33]

# %%
# gives the count of the item in the list
l.count(33)
# Out:
# 3

# %%
# this will sort the item in ascending order
l.sort()

# %%
l
# Out:
# [1, 6, 32, 33, 33, 33, 90, 100, 667]

# %%
# this will sort in descending order
l.sort(reverse=True)

# %%
l
# Out:
# [667, 100, 90, 33, 33, 33, 32, 6, 1]

# %%
l2 = [33, 6, 1, 667, 32, 90, 100]

# %%
# this will return the new list in sorted manned but will not sort the original list
sorted(l2)
# Out:
# [1, 6, 32, 33, 90, 100, 667]

# %%
l2
# Out:
# [33, 6, 1, 667, 32, 90, 100]

# %%
sorted_l2 = sorted(l2)

# %%
sorted_l2
# Out:
# [1, 6, 32, 33, 90, 100, 667]

# %%
new_l = [22, 33, 44, 11, 222]

# %%
# you can use this copy list to keep you original list unchanged and perform the task on the copy
copy_l = new_l.copy()

# %%
copy_l
# Out:
# [22, 33, 44, 11, 222]

# %%
copy_l.clear()

# %%
copy_l
# Out:
# []

# %%
# nested list or list in list
l = [1, 2, 5, 8, [44, 22]]

# %%
l[1]
# Out:
# 2

# %%
l[4]
# Out:
# [44, 22]

# %%
l[4][1]
# Out:
# 22

# %%
# list concatenation - this will not change the original list
l1 = [1, 2, 4]
l2 = [11, 22, 33]

# %%
l1 + l2
# Out:
# [1, 2, 4, 11, 22, 33]

# %%
l1
# Out:
# [1, 2, 4]

# %%
l2
# Out:
# [11, 22, 33]

# %%
#  membership in list - we can use this as conditions
if (11 in l2):
    print('11 is present in l2')
# Out:
# 11 is present in l2

# %%
11 in l2
# Out:
# True

# %%
1 in l2
# Out:
# False
