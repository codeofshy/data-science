# %% [markdown]
# ## f-string are the easiest way to format your string
# - string is immutable.
# - you can only change the variable but cannot mutate the string.
# - even the string methods does not actually mutate the string it returns you a new string and does not change your existing string.

# %%
s = "Shayan ahmed khan"

# %%
s.upper()
# Out:
# 'SHAYAN AHMED KHAN'

# %%
s.swapcase()
# Out:
# 'sHAYAN AHMED KHAN'

# %%
s
# Out:
# 'Shayan ahmed khan'

# %%
s.split()
# Out:
# ['Shayan', 'ahmed', 'khan']

# %%
# method 1
name = 'Shy'
age = 25

print('Hello my name is {} and my age is {}.'.format(name, age))
# Out:
# Hello my name is Shy and my age is 25.

# %%
print("{0} is learning {1}".format("Alice", "Python"))  # Using positions
print("{name} is learning {language}".format(name="Alice", language="Python"))
# Out:
# Alice is learning Python
# Alice is learning Python

# %%
# method 2 : most easiest and famous
name = 'Shy'
age = 25

print(f'Hello my name is {name} and my age is {age}.')
# Out:
# Hello my name is Shy and my age is 25.

# %%
a = 5
b = 10
print(f"Sum of {a} and {b} is {a + b}")
# Output: Sum of 5 and 10 is 15
# Out:
# Sum of 5 and 10 is 15

# %%
pi = 3.14159
print(f"Pi rounded to 2 decimal places: {pi:.2f}")
# Output: Pi rounded to 2 decimal places: 3.14
# Out:
# Pi rounded to 2 decimal places: 3.14

# %%
print(f"{'Python':<10}")  # Left-align
print(f"{'Python':>10}")  # Right-align
print(f"{'Python':^10}")  # Center-align
# Out:
# Python
#     Python
#   Python

# %%
'''
:<10 → The < symbol means left-align the text within a total width of 10 characters.

F-strings are the most efficient and recommended way to format strings in modern Python!
'''
# Out:
# '\n:<10 → The < symbol means left-align the text within a total width of 10 characters.\n\nF-strings are the most efficient and recommended way to format strings in modern Python!\n'
