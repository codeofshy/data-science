# %%
name = "shayan"

# %%
name
# Out:
# 'shayan'

# %%
print(name)
# Out:
# shayan

# %%
name.upper()
# Out:
# 'SHAYAN'

# %%
name.endswith("n")
# Out:
# True

# %%
name.endswith("N")
# Out:
# False

# %%
name.startswith("sh")
# Out:
# True

# %%
name.count("a")
# Out:
# 2

# %%
len(name)
# Out:
# 6

# %%
name.capitalize()
# Out:
# 'Shayan'

# %%
"shayan ahmed khan".title()
# Out:
# 'Shayan Ahmed Khan'

# %%
name.replace("a","X")
# Out:
# 'shXyXn'

# %%
n = 'Shayan Ahmed Khan'

# %%
l1 = n.split()

# %%
l1
# Out:
# ['Shayan', 'Ahmed', 'Khan']

# %%
"-".join(l1)
# Out:
# 'Shayan-Ahmed-Khan'

# %%
n.find('n') # find returns the 1st occurence.
# Out:
# 5

# %%
n[0:8]
# Out:
# 'Shayan A'

# %%
n[::2]
# Out:
# 'Saa he hn'

# %%
n[::3]
# Out:
# 'Sy m a'

# %%
n[-1]
# Out:
# 'n'

# %%
n[-5:] # negative indices can be treated as len(n)-5
# Out:
# ' Khan'

# %%
len(n)
# Out:
# 17

# %%
n[12:]
# Out:
# ' Khan'
