# %%
print("Shayan Ahmed Khan")
# Out:
# Shayan Ahmed Khan

# %% [markdown]
# # Python programming
# - It is a general purpose object oriented programming language.
# - Python is both compiled and interpreted, but it is classified as an interpreted language.

# %%
a = 3

# %%
b = 4

# %%
a + b
# Out:
# 7

# %%
a
# Out:
# 3

# %%
s1 = 4545

# %%
s1 = "shayan"

# %%
s1
# Out:
# 'shayan'
