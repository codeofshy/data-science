# %%
import seaborn as sns
import numpy as np

sns.set_theme(style='dark')
# sns.set_theme(style='darkgrid')

x = np.array([1,2, 3, 44, 67, 89, 90])
y = np.sin(x)

sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
