# %%
import pandas as pd

# %%
# read a csv file
df = pd.read_csv('data.csv')

df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df = df[df["IMDb"] > 6.0]

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
# this will create the csv file but the first column will be there of dataFrame index as shown above
df.to_csv("data_updated.csv")

# %%
# If you don't want to add the index as the first column
df.to_csv("data_updated_2.csv", index=False)

# %% [markdown]
# # Read json

# %%
df = pd.read_json("my.json")

# %%
df
# Out:
#    Id   Name                                Address
# 0   1  Alice  {'City': 'Mumbai', 'Pincode': 123231}
# 1   2   Lucy  {'City': 'Mumbai', 'Pincode': 123231}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       2 non-null      int64
#  1   Name     2 non-null      object
#  2   Address  2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 180.0+ bytes

# %%
data = [
    {"Id" : 1, "Name" : "Alice", "Address" : {"City" : "Mumbai", "Pincode" : 123231}},
    {"Id" : 2, "Name" : "Lucy", "Address" : {"City" : "Mumbai", "Pincode" : 123231}}
]

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#    Id   Name Address.City  Address.Pincode
# 0   1  Alice       Mumbai           123231
# 1   2   Lucy       Mumbai           123231
