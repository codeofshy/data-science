# %% [markdown]
# ## print

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
name, age = 'Shayan', 25.7
print(f'Hello my name is {name} and age is {age}.')
# Out:
# Hello my name is Shayan and age is 25.7.

# %% [markdown]
# # type casting

# %%
n = 17

# %%
n
# Out:
# 17

# %%
type(n)
# Out:
# int

# %%
float(n)
# Out:
# 17.0

# %%
n # type of n did not changed as I haven't assigned it
# Out:
# 17

# %%
n = complex(n)

# %%
n
# Out:
# (17+0j)

# %%
bool(12)
# Out:
# True

# %% [markdown]
# # string

# %%
n = "shayan ahmed khan" # string is immutable

# %%
n.upper()
# Out:
# 'SHAYAN AHMED KHAN'

# %%
n
# Out:
# 'shayan ahmed khan'

# %%
n.title()
# Out:
# 'Shayan Ahmed Khan'

# %%
n.endswith("khan")
# Out:
# True

# %%
n.startswith('SHA')
# Out:
# False

# %%
n.replace('a', "@")
# Out:
# 'sh@y@n @hmed kh@n'

# %%
n.removesuffix('khan')
# Out:
# 'shayan ahmed '

# %%
n.find('ahmed')
# Out:
# 7

# %%
n.find('a')
# Out:
# 2

# %%
n.replace('ahmed', 'A.')
# Out:
# 'shayan A. khan'

# %%
n.split()
# Out:
# ['shayan', 'ahmed', 'khan']

# %%
name = 'shayan'

# %%
name.split()
# Out:
# ['shayan']

# %%
n
# Out:
# 'shayan ahmed khan'

# %%
print(n[::-1])
# Out:
# nahk demha nayahs

# %%
n[:7]
# Out:
# 'shayan '

# %%
len(n)
# Out:
# 17

# %% [markdown]
# # Operators

# %%
# arithematic operator : +, -, *, /, +=, -=, *=, //, %

# %%
a = 0

# %%
a += 5
a
# Out:
# 5

# %%
a += 10
a
# Out:
# 15

# %%
a *= 2
a
# Out:
# 30

# %%
a %= 7
a
# Out:
# 2

# %%
# comparison operator : ==, <=, >=, !=,

# %%
3 != 5
# Out:
# True

# %%
# logical operator : and, or, not

# %% [markdown]
# # input

# %%
name = input()
# Out:
#  shayan

# %%
age = input('Enter your age : ')   # input is always str
age
# Out:
# Enter your age :  25.6
# '25.6'

# %% [markdown]
# # Operators presedence
# - PEMDAS

# %%
result = 10 + 2 * 3  # Multiplication happens first: 10 + (2 * 3) = 16
print(result)

result = (10 + 2) * 3  # Parentheses first: (10 + 2) * 3 = 36
print(result)

result = 2 ** 3 ** 2  # Right-to-left exponentiation: 2 ** (3 ** 2) = 2 ** 9 = 512
print(result)
# Out:
# 16
# 36
# 512

# %% [markdown]
# # if else

# %%
if True:
    print('condition is true.')
