# %% [markdown]
# # Python revision

# %%
# string replace method
s = 'shayan'
s = s.replace('a', 'x')
s
# Out:
# 'shxyxn'

# %%
# split method

a = 'shayan'
l = 'this is a string'

print(a.split())
print(l.split())
# Out:
# ['shayan']
# ['this', 'is', 'a', 'string']

# %%
s = ['this', 'is', 'a', 'string']
s = "-".join(s)
s
# Out:
# 'this-is-a-string'

# %%
'shaaaayaan'.count('a')
# Out:
# 6

# %%
'shaaaayaan'.find('y')
# Out:
# 6

# %%
import pandas as pd

data = {'Name' : ['shayan', 'harry', 'ali'], 'Score' : [99, 86, 45]}
df = pd.DataFrame(data)

# df
df['Result'] = df['Score'].apply(lambda x : 'Pass' if x > 50 else "Fail")
df
# Out:
#      Name  Score Result
# 0  shayan     99   Pass
# 1   harry     86   Pass
# 2     ali     45   Fail

# %%
# match

day = 40
match day:
    case 1 : print('Monday')
    case 2 : print('Tue')
    case 3 : print('Wed')
    case 4 : print('Thu')
    case 5 : print('Fri')
    case _ : print('invalid input')
# Out:
# invalid input

# %%
# excercise to find the runner up
num = [4, 5, 6, 6, 7]
num = list(set(num))
max_num = max(num)
# max_num
num.remove(max_num)
# num
print(max(num))
# Out:
# 6

# %%
l = [4,6,3,6,9,3,1,6,9,4]
l.sort()
# l.sort(reverse=True)
l
# l.reverse()
# l
# l.reverse()
# Out:
# [9, 9, 6, 6, 6, 4, 4, 3, 3, 1]

# %%
person = dict(name = 'shy', age = 25, gender = 'male')

# %%
person
# Out:
# {'name': 'shy', 'age': 25, 'gender': 'male'}

# %%
person['contact'] = 345345632

# %%
person
# Out:
# {'name': 'shy', 'age': 25, 'gender': 'male', 'contact': 345345632}

# %%
# check if the file exist
import os

if os.path.exists('01-Introduction_to_Data_Science.pdf') : print('Present')
else : print('File does not exist')
# Out:
# Present

# %%
with open('test.txt', 'w') as f:
    content = 'This is the first line.'
    f.write(content)

# %%
with open('test.txt') as f:
    print(f.read())
# Out:
# This is the first line.

# %%
file = open('test.txt')
content = file.read()
print(content)
file.close()
# Out:
# This is the first line.
# This is the next line of the file

# %%
f = open('test.txt', 'a')
content = '\nThis is the next line of the file'
f.write(content)
f.close()

# %%
with open('test.txt', 'r') as f:
    print(f.read())
# Out:
# This is the first line.
# This is the next line of the file

# %%
import os

if os.path.exists('test123.txt') : 
    print('The file is present')
else : 
    print("file is not present")
# Out:
# file is not present
